# %% [markdown]
# # Exercises
#
# For these exercises, you'll need to load the tidyverse and rvest packages.

# %%
## load tidyverse
suppressPackageStartupMessages(library(tidyverse))
suppressPackageStartupMessages(library(rvest))

# %% [markdown]
# ### R basics
#
# **1. Why does the following code not work?**

# %%
my_variable <- 10
my_varıable
##typo in display text
# Out:
# Error in parse(text = x, srcfile = src): <text>:2:14: unexpected '>'
# 1: my_variable <- 10
# 2: my_var<U+0131>
#                 ^
# Traceback:

# %%
my_variable <- 10
my_variable
# Out:
# [1] 10

# %% [markdown]
# **2. Tweak each of the following R commands so that they run correctly**

# %%
## fix the code below
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy))
##"dota" to "data"
# Out:
# plot without title

# %%
## fix the code below
filter(mpg, cyl == 8)
# Out:
#        manufacturer model                  displ  year   cyl    trans
# 1      audi         a6 quattro             4.2    2008   8      auto(s6)
# 2      chevrolet    c1500 suburban 2wd     5.3    2008   8      auto(l4)
# 3      chevrolet    c1500 suburban 2wd     5.3    2008   8      auto(l4)
# 4      chevrolet    c1500 suburban 2wd     5.3    2008   8      auto(l4)
# 5      chevrolet    c1500 suburban 2wd     5.7    1999   8      auto(l4)
# 6      chevrolet    c1500 suburban 2wd     6.0    2008   8      auto(l4)
# 7      chevrolet    corvette               5.7    1999   8      manual(m6)
# 8      chevrolet    corvette               5.7    1999   8      auto(l4)
# 9      chevrolet    corvette               6.2    2008   8      manual(m6)
# 10     chevrolet    corvette               6.2    2008   8      auto(s6)
# 11     chevrolet    corvette               7.0    2008   8      manual(m6)
# 12     chevrolet    k1500 tahoe 4wd        5.3    2008   8      auto(l4)
# ...

# %%
## fix the code below
filter(diamonds, carat > 3)
# Out:
#    carat cut       color clarity depth table price x     y     z
# 1  3.01  Premium   I     I1      62.7  58     8040  9.10  8.97 5.67
# 2  3.11  Fair      J     I1      65.9  57     9823  9.15  9.02 5.98
# 3  3.01  Premium   F     I1      62.2  56     9925  9.24  9.13 5.73
# 4  3.05  Premium   E     I1      60.9  58    10453  9.26  9.25 5.66
# 5  3.02  Fair      I     I1      65.2  56    10577  9.11  9.02 5.91
# 6  3.01  Fair      H     I1      56.1  62    10761  9.54  9.38 5.31
# 7  3.65  Fair      H     I1      67.1  53    11668  9.53  9.48 6.38
# 8  3.24  Premium   H     I1      62.1  58    12300  9.44  9.40 5.85
# 9  3.22  Ideal     I     I1      62.6  55    12545  9.49  9.42 5.92
# 10 3.50  Ideal     H     I1      62.8  57    12587  9.65  9.59 6.03
# 11 3.01  Premium   G     SI2     59.8  58    14220  9.44  9.37 5.62
# 12 4.01  Premium   I     I1      61.0  61    15223 10.14 10.10 6.17
# 13 4.01  Premium   J     I1      62.5  62    15223 10.02  9.94 6.24
# ...

# %% [markdown]
# **3. Select the first, third, and fifth rows of the `mtcars` data set**.

# %%
## your code goes here
head(mtcars, 5)
# Out:
#                   mpg  cyl disp hp  drat wt    qsec  vs am gear carb
# Mazda RX4         21.0 6   160  110 3.90 2.620 16.46 0  1  4    4
# Mazda RX4 Wag     21.0 6   160  110 3.90 2.875 17.02 0  1  4    4
# Datsun 710        22.8 4   108   93 3.85 2.320 18.61 1  1  4    1
# Hornet 4 Drive    21.4 6   258  110 3.08 3.215 19.44 1  0  3    1
# Hornet Sportabout 18.7 8   360  175 3.15 3.440 17.02 0  0  3    2

# %%
mtcars[c(1,3,5),]
# Out:
#                   mpg  cyl disp hp  drat wt   qsec  vs am gear carb
# Mazda RX4         21.0 6   160  110 3.90 2.62 16.46 0  1  4    4
# Datsun 710        22.8 4   108   93 3.85 2.32 18.61 1  1  4    1
# Hornet Sportabout 18.7 8   360  175 3.15 3.44 17.02 0  0  3    2

# %% [markdown]
# **4. Select the columns for all variable whose names start with "c" in the `diamonds` data set.**

# %%
## your code goes here
head(diamonds,1)
# Out:
#   carat cut   color clarity depth table price x    y    z
# 1 0.23  Ideal E     SI2     61.5  55    326   3.95 3.98 2.43

# %%
diamonds[,c(1:4)]
# Out:
#        carat  cut       color  clarity
# 1      0.23   Ideal     E      SI2
# 2      0.21   Premium   E      SI1
# 3      0.23   Good      E      VS1
# 4      0.29   Premium   I      VS2
# 5      0.31   Good      J      SI2
# 6      0.24   Very Good J      VVS2
# 7      0.24   Very Good I      VVS1
# 8      0.26   Very Good H      SI1
# 9      0.22   Fair      E      VS2
# 10     0.23   Very Good H      VS1
# 11     0.30   Good      J      SI1
# 12     0.23   Ideal     J      VS1
# 13     0.22   Premium   F      SI1
# 14     0.31   Ideal     J      SI2
# 15     0.20   Premium   E      SI2
# 16     0.32   Premium   E      I1
# 17     0.30   Ideal     I      SI2
# 18     0.30   Good      J      SI1
# 19     0.30   Good      J      SI1
# 20     0.30   Very Good J      SI1
# 21     0.30   Good      I      SI2
# 22     0.23   Very Good E      VS2
# 23     0.23   Very Good H      VS1
# 24     0.31   Very Good J      SI1
# 25     0.31   Very Good J      SI1
# ...

# %% [markdown]
# **5. Use the `lapply()` function to find the class of each variable in the `mtcars` data set.**

# %%
## your code goes here
head(lapply(mtcars, function(x) class(x)))
# Out:
# $mpg
# [1] "numeric"
#
# $cyl
# [1] "numeric"
#
# $disp
# [1] "numeric"
#
# $hp
# [1] "numeric"
#
# $drat
# [1] "numeric"
#
# $wt
# [1] "numeric"

# %% [markdown]
# ### Web scraping
#
# **6. Now, finish the code below, scraping the [wikipedia page on land use](https://en.wikipedia.org/wiki/Land_use_statistics_by_country) and storing it as an R object named `landuse`.**

# %%
## land use
landuse_url <- "https://en.wikipedia.org/wiki/Land_use_statistics_by_country"

## your code goes here
landuse <- read_html("https://en.wikipedia.org/wiki/Land_use_statistics_by_country")

# %% [markdown]
# **7. Extract and print any tables scraped from the wikipedia page. Then, select the table that has variables named country, cultivated land, arable land, permanent crops, other lands, total area, date, etc. and store it as an R object named `landuse_df`.**

# %%
## your code goes here
landusetabs <- html_table(landuse)
landusetabs
# Out:
# [[1]]
#         Rank                                      Country
# 1   <U+2014>                                        World
# 2          1                                        India
# 3          2                                United States
# 4          3                                        China
# 5          4                                       Russia
# 6          5                                       Brazil
# 7          6                                       Canada
# 8          7                                    Australia
# 9          8                                    Indonesia
# 10         9                                      Nigeria
# 11        10                                    Argentina
# 12        11                                      Ukraine
# 13        12                                        Sudan
# 14        13                                       Mexico
# 15        14                                   Kazakhstan
# ...

# %%
landuse_df <- landusetabs[[1]]
landuse_df
# Out:
#        Rank     Country
# 1      <U+2014> World
# 2      1        India
# 3      2        United States
# 4      3        China
# 5      4        Russia
# 6      5        Brazil
# 7      6        Canada
# 8      7        Australia
# 9      8        Indonesia
# 10     9        Nigeria
# 11     10       Argentina
# 12     11       Ukraine
# 13     12       Sudan
# 14     13       Mexico
# 15     14       Kazakhstan
# 16     15       Turkey
# 17     16       Pakistan
# 18     17       France
# 19     18       Thailand
# 20     19       Iran
# 21     20       Ethiopia
# 22     21       Spain
# 23     22       Tanzania
# 24     23       Niger
# 25     24       Burma
# 26     25       South Africa
# 27     26       Germany
# 28     27       Uganda
# 29     28       Poland
# 30     29       Vietnam
# <U+22EE> <U+22EE> <U+22EE>
# 210    194      Bermuda
# 211    <U+2014> Turks and Caicos Islands
# 212    195      San Marino
# 213    <U+2014> Cayman Islands
# 214    196      Andorra
# ...

# %% [markdown]
# The final three questions ask you to clean up the `landuse_df` data frame.
#
# **8. First, give `landuse_df` better variable names---lower case, no spaces or non-alphanumeric characters, etc.**

# %%
## your code goes here
names(landuse_df) <- c("rank", "country", "cultivated_land_km2", "cultivated_land_percent", "arable_land_km2", "arable_land_percent", "permanent_crops_km2", "permanent_crops_percent", "other_lands_km2", "other_lands_percent", "total_area_km2", "date")

# %%
#replace dashes?
landuse_df[, 1:ncol(landuse_df)] <- lapply(landuse_df, stringr::str_replace_all, "−|\u2212", "-")

# %%
head(landuse_df,1)
# Out:
#   rank     country cultivated_land_km2 cultivated_land_percent arable_land_km2
# 1 <U+2014> World   17,235,800          11.6                    15,749,300
#   arable_land_percent permanent_crops_km2 permanent_crops_percent
# 1 10.6                1,549,600           1
#   other_lands_km2 other_lands_percent total_area_km2 date
# 1 131.701.100     88.4                149,000,000    2011

# %% [markdown]
# **9. Clean and convert all appropriate columns to numeric.**

# %%
## your code goes here
## identify the column(s) that should probably be considered integer or numeric
nums <- c("rank", "cultivated_land_km2", "cultivated_land_percent", "arable_land_km2", "arable_land_percent", "permanent_crops_km2", "permanent_crops_percent", "other_lands_km2", "other_lands_percent", "total_area_km2", "date")

## remove everything that's not a number, minus sign, or decimal and convert to numeric
landuse_df[nums] <- lapply(landuse_df[nums], function(x)
  as.numeric(stringr::str_replace_all(x, "[^[:digit:]\\-\\.]", "")))

## set rank var as integer
landuse_df$rank <- as.integer(landuse_df$rank)

## preview data
landuse_df
# Out:
# Warning message in FUN(X[[i]], ...):
# "NAs introduced by coercion"
#        rank   country                                      cultivated_land_km2
# 1      NA     World                                        17235800
# 2       1     India                                         1891761
# 3       2     United States                                 1681826
# 4       3     China                                         1238013
# 5       4     Russia                                        1265267
# 6       5     Brazil                                         800485
# 7       6     Canada                                         519205
# 8       7     Australia                                      487695
# 9       8     Indonesia                                      478055
# 10      9     Nigeria                                        412938
# 11     10     Argentina                                      397598
# 12     11     Ukraine                                        347673
# ...

# %% [markdown]
# **10. Using the {ggplot2} package, create a visualization depicting the amount of cultivated and arable land areas for India, United States, China, and Russia.**

# %%
## your code goes here
##step one: limit to India, US, China, Russia
#example <- c("India", "United States", "China", "Russia")

LU1 <- subset(landuse_df[c(2:5),])

LU1
# Out:
#   rank country       cultivated_land_km2 cultivated_land_percent
# 2 1    India         1891761             57.0
# 3 2    United States 1681826             17.1
# 4 3    China         1238013             12.9
# 5 4    Russia        1265267              7.4
#   arable_land_km2 arable_land_percent permanent_crops_km2
# 2 1753694         52.8                138067
# 3 1652028         16.8                 29798
# 4 1084461         11.3                153552
# 5 1248169          7.3                 17098
#   permanent_crops_percent other_lands_km2 other_lands_percent total_area_km2
# 2 4.2                      1395502        43.0                 3287263
# 3 0.3                      8151691        82.9                 9833517
# 4 1.6                      8358947        87.1                 9596960
# 5 0.1                     15832975        92.6                17098242
#   date
# 2 2011
# 3 2011
# 4 2011
# 5 2011

# %%
LU2 <- subset(LU1[,c(2,3,5)])
LU2
# Out:
#   country       cultivated_land_km2 arable_land_km2
# 2 India         1891761             1753694
# 3 United States 1681826             1652028
# 4 China         1238013             1084461
# 5 Russia        1265267             1248169

# %%
suppressPackageStartupMessages(library(reshape2))

# %%
meltLU3 <- melt(LU2, id.vars = "country")
meltLU3
# Out:
#   country       variable            value
# 1 India         cultivated_land_km2 1891761
# 2 United States cultivated_land_km2 1681826
# 3 China         cultivated_land_km2 1238013
# 4 Russia        cultivated_land_km2 1265267
# 5 India         arable_land_km2     1753694
# 6 United States arable_land_km2     1652028
# 7 China         arable_land_km2     1084461
# 8 Russia        arable_land_km2     1248169

# %%
ggplot(data=meltLU3, aes(x=country, y=value, fill=variable))+ geom_bar(stat="identity", position="dodge")
# Out:
# plot without title
